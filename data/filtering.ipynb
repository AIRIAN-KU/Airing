# %%
import pandas as pd

data = pd.read_csv('2022년_여행객수.csv')

data
# Out:
#       home_loc_cd   trv_idx  age_cd loc_type home_loc_nm  sex_cd      yw  \
# 0              11  0.075274      10     sido       서울특별시       1  202206
# 1              11  0.116060      30     sido       서울특별시       1  202206
# 2              11  0.049257      70     sido       서울특별시       1  202206
# 3              11  0.132056      50     sido       서울특별시       1  202206
# 4              11  0.118519      20     sido       서울특별시       1  202206
# ...           ...       ...     ...      ...         ...     ...     ...
# 3259           50  0.105178      30     sido     제주특별자치도       2  202203
# 3260           50  0.074594      60     sido     제주특별자치도       2  202203
# 3261           50  0.082560      10     sido     제주특별자치도       2  202203
# 3262           50  0.089429      50     sido     제주특별자치도       2  202203
# 3263           50  0.071286       0     sido     제주특별자치도       2  202203
#
#       id_cnt                       date
# 0     159855  2022-02-05T00:00:00+09:00
# ...

# %%
filtered = data[data['home_loc_nm'] == '서울특별시']
# Out:
#       home_loc_cd   trv_idx  age_cd loc_type home_loc_nm  sex_cd      yw  \
# 0              11  0.075274      10     sido       서울특별시       1  202206
# 1              11  0.116060      30     sido       서울특별시       1  202206
# 2              11  0.049257      70     sido       서울특별시       1  202206
# 3              11  0.132056      50     sido       서울특별시       1  202206
# 4              11  0.118519      20     sido       서울특별시       1  202206
# ...           ...       ...     ...      ...         ...     ...     ...
# 3131           11  0.066615      60     sido       서울특별시       2  202203
# 3132           11  0.106925      30     sido       서울특별시       2  202203
# 3133           11  0.094885       0     sido       서울특별시       2  202203
# 3134           11  0.089105      10     sido       서울특별시       2  202203
# 3135           11  0.099808      40     sido       서울특별시       2  202203
#
#       id_cnt                       date
# 0     159855  2022-02-05T00:00:00+09:00
# ...

# %%
filtered.to_csv('filtered_2022_여행객수.csv', index=False)
